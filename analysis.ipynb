# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\ojhak\OneDrive\Desktop\Python\Project MRP\data_150.csv")
df.head()
# Out:
#    respondent_id  brand_tribalism  brand_love
# 0              1             3.02        2.68
# 1              2             3.07        3.65
# 2              3             4.14        4.13
# 3              4             4.61        4.63
# 4              5             4.04        3.63

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   respondent_id    150 non-null    int64
#  1   brand_tribalism  150 non-null    float64
#  2   brand_love       150 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 3.6 KB
#        respondent_id  brand_tribalism  brand_love
# count     150.000000       150.000000  150.000000
# mean       75.500000         3.544267    3.466600
# std        43.445368         0.888310    0.676078
# min         1.000000         2.010000    2.060000
# 25%        38.250000         2.700000    2.905000
# 50%        75.500000         3.550000    3.515000
# 75%       112.750000         4.377500    3.985000
# max       150.000000         4.990000    4.840000

# %%
df.corr()
# Out:
#                  respondent_id  brand_tribalism  brand_love
# respondent_id         1.000000        -0.037998    0.003595
# brand_tribalism      -0.037998         1.000000    0.908182
# brand_love            0.003595         0.908182    1.000000

# %%
plt.scatter(df["brand_tribalism"], df["brand_love"])
plt.xlabel("Brand Tribalism")
plt.ylabel("Brand Love")
plt.title("Brand Tribalism vs Brand Love")
plt.show()

# %%
# !pip install scikit-learn
import sklearn
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn.linear_model import LinearRegression

X = df[["brand_tribalism"]]
y = df["brand_love"]

model = LinearRegression()
model.fit(X, y)

print("Coefficient:", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Coefficient: 0.6912024501520739
# Intercept: 1.0167941960076763

# %%
from sklearn.linear_model import LinearRegression

X = df[["brand_tribalism"]]
y = df["brand_love"]

model = LinearRegression()
model.fit(X, y)

print("Coefficient:", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Coefficient: 0.6912024501520739
# Intercept: 1.0167941960076763
